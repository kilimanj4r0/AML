# %% [markdown]
# # Training YOLOv8 on Custom Dataset

# %%
# !nvidia-smi
# Out:
# Wed May  3 21:02:27 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
HOME
# Out:
# '/content'

# %% [markdown]
# ## Install YOLOv8

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.5/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## Loading Custom Dataset from Roboflow

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="Yvybg7OmHGRJFqqIIPaG")
project = rf.workspace("university-msm2s").project("graduated-flask-segmentation")
dataset = project.version(2).download("yolov8")
# Out:
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Graduated-Flask-segmentation-2 to yolov8: 100% [28469241 / 28469241] bytes
# Extracting Dataset Version Zip to Graduated-Flask-segmentation-2 in yolov8:: 100%|██████████| 1036/1036 [00:00<00:00, 1615.34it/s]

# %% [markdown]
# ## Training on Custom Dataset

# %%
# %cd {HOME}

# !yolo task=segment mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.yaml, data=/content/datasets/Graduated-Flask-segmentation-2/data.yaml, epochs=25, patience=50, batch=16, imgsz=800, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train3
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 109MB/s]
# 2023-05-03 21:03:11.781829: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-03 21:03:12.756249: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.Detect                [3, [64, 128, 256]]
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/datasets/Graduated-Flask-segmentation-2/train/labels... 447 images, 0 backgrounds, 0 corrupt: 100% 447/447 [00:00<00:00, 1806.15it/s]
# train: New cache created: /content/datasets/Graduated-Flask-segmentation-2/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Graduated-Flask-segmentation-2/valid/labels... 42 images, 0 backgrounds, 0 corrupt: 100% 42/42 [00:00<00:00, 1877.91it/s]
# val: New cache created: /content/datasets/Graduated-Flask-segmentation-2/valid/labels.cache
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      3.63G       1.27      3.394      1.387         99        800: 100% 28/28 [00:27<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.19s/it]
#                    all         42        118    0.00464      0.553      0.308      0.209
#        graduated-flask         42         42    0.00809          1      0.732      0.494
#           liquid-level         42         38    0.00108     0.0789   0.000607   9.95e-05
#    liquid-level-length         42         38    0.00476      0.579       0.19      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      3.64G     0.8917       1.69      1.043        121        800: 100% 28/28 [00:18<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  3.26it/s]
#                    all         42        118          1      0.297      0.581      0.467
#        graduated-flask         42         42          1      0.892      0.995      0.796
#           liquid-level         42         38          1          0      0.113     0.0858
#    liquid-level-length         42         38          1          0      0.634      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      3.64G       0.91       1.28      1.019        115        800: 100% 28/28 [00:18<00:00,  1.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.39it/s]
#                    all         42        118      0.903      0.529      0.821      0.588
#        graduated-flask         42         42      0.827          1      0.976       0.71
#           liquid-level         42         38          1          0      0.581      0.323
#    liquid-level-length         42         38      0.881      0.587      0.907      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      3.64G     0.9096      1.183      1.008         81        800: 100% 28/28 [00:18<00:00,  1.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.50it/s]
#                    all         42        118      0.901      0.856      0.905      0.671
#        graduated-flask         42         42      0.858          1      0.991      0.704
#           liquid-level         42         38      0.922      0.625      0.766       0.52
#    liquid-level-length         42         38      0.923      0.943      0.957      0.789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      3.64G     0.8923       1.05     0.9818         89        800: 100% 28/28 [00:20<00:00,  1.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  3.07it/s]
#                    all         42        118      0.925      0.837      0.901      0.682
#        graduated-flask         42         42      0.914          1      0.995      0.743
#           liquid-level         42         38      0.914      0.557      0.744      0.499
#    liquid-level-length         42         38      0.948      0.955      0.963      0.804
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      3.64G     0.8298      1.007      0.965         92        800: 100% 28/28 [00:17<00:00,  1.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  3.26it/s]
#                    all         42        118      0.976       0.87      0.926      0.745
#        graduated-flask         42         42      0.981          1      0.995       0.85
#           liquid-level         42         38          1       0.61      0.813      0.545
#    liquid-level-length         42         38      0.946          1      0.969      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25
0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25      3.64G     0.5518     0.6972     0.8831         43        800: 100% 28/28 [00:11<00:00,  2.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.25it/s]
#                    all         42        118      0.969       0.93      0.968      0.838
#        graduated-flask         42         42      0.989          1      0.995      0.912
#           liquid-level         42         38      0.959      0.789      0.931      0.683
#    liquid-level-length         42         38      0.958          1       0.98      0.919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      3.64G     0.5279     0.6613     0.8811         39        800: 100% 28/28 [00:10<00:00,  2.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.29it/s]
#                    all         42        118       0.96       0.96      0.979      0.866
#        graduated-flask         42         42      0.983          1      0.995      0.933
#           liquid-level         42         38      0.943      0.879      0.963      0.733
#    liquid-level-length         42         38      0.955          1      0.978      0.932
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      3.64G     0.5115     0.6382     0.8787         43        800: 100% 28/28 [00:10<00:00,  2.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.28it/s]
#                    all         42        118      0.911      0.974      0.967      0.841
#        graduated-flask         42         42      0.985          1      0.995      0.939
#           liquid-level         42         38      0.803      0.921      0.924      0.669
#    liquid-level-length         42         38      0.945          1      0.984      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      3.64G     0.4983     0.6191       0.87         44        800: 100% 28/28 [00:10<00:00,  2.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.40it/s]
#                    all         42        118       0.89      0.967      0.948      0.836
#        graduated-flask         42         42      0.986          1      0.995      0.906
#           liquid-level         42         38      0.725        0.9      0.859      0.654
#    liquid-level-length         42         38       0.96          1      0.991      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25      3.64G     0.4838     0.5992     0.8632         45        800: 100% 28/28 [00:11<00:00,  2.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.89it/s]
#                    all         42        118      0.902      0.988      0.965      0.863
#        graduated-flask         42         42      0.983          1      0.995      0.949
#           liquid-level         42         38      0.769      0.964      0.917      0.694
#    liquid-level-length         42         38      0.954          1      0.982      0.947
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25      3.64G     0.4578     0.5755     0.8628         45        800: 100% 28/28 [00:11<00:00,  2.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  3.20it/s]
#                    all         42        118      0.891      0.991       0.96      0.871
#        graduated-flask         42         42      0.982          1      0.995      0.966
#           liquid-level         42         38      0.737      0.974      0.898        0.7
#    liquid-level-length         42         38      0.954          1      0.986      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      3.64G     0.4392     0.5455     0.8471         45        800: 100% 28/28 [00:11<00:00,  2.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  3.30it/s]
#                    all         42        118      0.928      0.975      0.979      0.866
#        graduated-flask         42         42      0.987          1      0.995      0.942
#           liquid-level         42         38      0.834      0.926      0.958      0.717
#    liquid-level-length         42         38      0.961          1      0.984      0.938
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      3.64G      0.433     0.5432     0.8497         43        800: 100% 28/28 [00:11<00:00,  2.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.72it/s]
#                    all         42        118      0.944      0.964       0.98      0.884
#        graduated-flask         42         42       0.98          1      0.995      0.972
#           liquid-level         42         38      0.894      0.892      0.961      0.737
#    liquid-level-length         42         38      0.957          1      0.984      0.943
#
# 25 epochs completed in 0.123 hours.
# Optimizer stripped from runs/detect/train3/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train3/weights/best.pt, 6.2MB
#
# Validating runs/detect/train3/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.91it/s]
#                    all         42        118      0.944      0.964       0.98      0.882
#        graduated-flask         42         42       0.98          1      0.995      0.968
#           liquid-level         42         38      0.894      0.892      0.961      0.736
#    liquid-level-length         42         38      0.957          1      0.984      0.943
# Speed: 0.1ms pre-process, 3.5ms inference, 0.0ms loss, 1.9ms post-process per image
# Results saved to runs/detect/train3

# %% [markdown]
# ## Results

# %% [markdown]
# For some reason all runs saved in detect folder, not segment

# %%
# !ls {HOME}/runs/detect/train3/
# Out:
# args.yaml					    train_batch1.jpg
# confusion_matrix.png				    train_batch2.jpg
# events.out.tfevents.1683147794.89c7aa3c4486.9065.0  train_batch420.jpg
# F1_curve.png					    train_batch421.jpg
# P_curve.png					    train_batch422.jpg
# PR_curve.png					    val_batch0_labels.jpg
# R_curve.png					    val_batch0_pred.jpg
# results.csv					    val_batch1_labels.jpg
# results.png					    val_batch1_pred.jpg
# train_batch0.jpg				    weights

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ### Evaluation

# %%
# %cd {HOME}

# !yolo task=segment mode=val model={HOME}/runs/detect/train3/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# 2023-05-03 21:15:12.506040: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-03 21:15:13.594455: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/Graduated-Flask-segmentation-2/valid/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100% 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:02<00:00,  1.23it/s]
#                    all         42        118      0.944      0.964       0.98      0.891
#        graduated-flask         42         42       0.98          1      0.995      0.973
#           liquid-level         42         38      0.894      0.892      0.961      0.742
#    liquid-level-length         42         38      0.957          1      0.984      0.957
# Speed: 1.7ms pre-process, 13.9ms inference, 0.0ms loss, 6.7ms post-process per image

# %% [markdown]
# ### Inference

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model={HOME}/runs/detect/train3/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# 2023-05-03 21:15:53.611933: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-03 21:15:55.055381: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# image 1/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224205804_jpg.rf.8ea432548e90cc4b2dac8bdcc0d8487e.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 48.3ms
# image 2/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224205928_jpg.rf.47b8151f6790b8e6bc8f08069c30a20d.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.6ms
# image 3/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224210323_jpg.rf.43a50bcdee61819420a65b79eb21c6c3.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.0ms
# image 4/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224210528_jpg.rf.278db6685c2138260f287a853a1e8c74.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.0ms
# image 5/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224210737_jpg.rf.ca8c08937081d36fcfc6a5418173db9e.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.0ms
# image 6/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224210805_jpg.rf.32b82ca93b55d4f658a610e6099b3ad0.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.0ms
# image 7/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224211106_jpg.rf.2897df2639c3fbd3adfce73ac92479d2.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.0ms
# image 8/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224211222_jpg.rf.4c9ea6e1fdad7f1c5879869145f32c71.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.0ms
# image 9/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224211230_jpg.rf.b17a8effeb90de0a159236d0d36cd97f.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.0ms
# image 10/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224211359_jpg.rf.75783cc61c8b68af36ac171182196265.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.0ms
# image 11/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224211652_jpg.rf.40acb48c0f9342de29aab27976b75428.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.0ms
# image 12/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224211736_jpg.rf.e82b4416a8aec552bbb6622cec7563d4.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.0ms
# image 13/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224211841_jpg.rf.5673be12460d76632f646ac4dc5f529a.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.0ms
# image 14/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224212058_jpg.rf.3498c15cdeac4e9c286c73304eff96c5.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 6.0ms
# image 15/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224212243_jpg.rf.0c309a3d72d8c6733111e75ddb2329ce.jpg: 800x384 1 graduated-flask, 6.0ms
# image 16/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224212328_jpg.rf.2537523608293aa87b554c60c8b1ae32.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 5.9ms
# image 17/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224212351_jpg.rf.523682aa2653ac03a275c92211096c91.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 5.8ms
# image 18/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224212519_jpg.rf.71e08b4ff95a5fa9f44bdca8c7693a55.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 5.9ms
# image 19/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224212619_jpg.rf.54aed66edc2bc5a79f314ade508da5e7.jpg: 800x384 1 graduated-flask, 3 liquid-levels, 1 liquid-level-length, 5.9ms
# image 20/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224212722_jpg.rf.bace3add0221f932ce9782665f88f4e9.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 5.9ms
# image 21/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224212855_jpg.rf.4f3c564682bfd1ee3485df16318c1964.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 5.8ms
# image 22/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224213030_jpg.rf.a990e9f9fb32840a0302d087b8c58364.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 5.9ms
# image 23/23 /content/datasets/Graduated-Flask-segmentation-2/test/images/IMG20230224213036_jpg.rf.1c252c719660159ef57379e99a0f06bf.jpg: 800x384 1 graduated-flask, 1 liquid-level, 1 liquid-level-length, 5.9ms
# Speed: 0.4ms pre-process, 7.8ms inference, 5.2ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/segment/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/segment/predict/*.jpg')[:3]:
      display(Image(filename=image_path, height=600))
      print("\n")
